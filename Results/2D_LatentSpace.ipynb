# %%
import matplotlib
import numpy as np

from molecules.model import MoleculeVAE
from molecules.utils import load_dataset
from pylab import figure, axes, scatter, title, show, savefig
import h5py    
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
f = h5py.File("encoded.h5",'r')

# %%
for key in f.keys():   
    print(f[key].name)  
    print(f[key].shape)  
    print(f[key].value)
# Out:
# /charset
# (51,)
# [b' ' b'(' b'.' b'0' b'2' b'4' b'6' b'8' b'@' b'B' b'F' b'H' b'N' b'P'
#  b'T' b'X' b'\\' b'b' b'l' b'n' b'p' b'r' b't' b'#' b'%' b')' b'+' b'-'
#  b'/' b'1' b'3' b'5' b'7' b'9' b'=' b'A' b'C' b'I' b'K' b'M' b'O' b'S'
#  b'[' b']' b'a' b'c' b'e' b'g' b'i' b'o' b's']
# /latent_vectors
# (10000, 292)
# [[-0.0392103   0.04080619 -0.13966934 ...  0.11050667 -0.00930338
#    0.05262267]
#  [-0.01234055  0.1602053   0.16650331 ... -0.16450925 -0.05734041
#    0.00239535]
#  [ 0.05622879  0.05587942 -0.06221618 ...  0.04074499 -0.01170248
#   -0.07868107]
#  ...
#  [ 0.02274758 -0.09979293  0.03960971 ... -0.01233994 -0.02051021
#    0.00523382]
#  [-0.02317438  0.07384009 -0.07702765 ...  0.07127422 -0.01172413
#    0.06676275]
#  [-0.0785789  -0.00497421 -0.17394759 ... -0.04760019  0.07646009
#    0.04815028]]

# %%
figure(figsize=(6, 6), dpi = 80)
scatter(f['latent_vectors'].value[:, 0], f['latent_vectors'].value[:, 1], marker = '.', linewidth = '0.5',  s = 1.5, c = 'darkgreen')
title('Dataset Projected onto 2D Latent Space', )
savefig('image2d.png', bbox_inches = 'tight')
show()
